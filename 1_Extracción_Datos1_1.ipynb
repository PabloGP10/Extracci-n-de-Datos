# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloGP10/Extracci-n-de-Datos/blob/main/1_Extracci%C3%B3n_Datos1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df= pd.read_csv("CountryTable.csv")
df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#               code         name                     region  surface_area  \
# continent
# North America  ABW        Aruba                  Caribbean         193.0
# Asia           AFG  Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO       Angola             Central Africa     1246700.0
# North America  AIA     Anguilla                  Caribbean          96.0
# Europe         ALB      Albania            Southern Europe       28748.0
#
#                independence_year  population  life_expectancy     gnp  \
# continent
# North America                NaN      103000             78.4   828.0
# Asia                      1919.0    22720000             45.9  5976.0
# Africa                    1975.0    12878000             38.3  6648.0
# North America                NaN        8000             76.1    63.2
# Europe                    1912.0     3401200             71.6  3205.0
#
#                gnp_old             local_name  \
# continent
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS **

# %%
#Filtro por objeto 
filtro1=df[df["continent"] == "Europe"]
filtro1

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Entregable1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro1.csv")

# %%
#Filtro por objeto 
filtro12=df[df["name"] == "Aruba"]
filtro12

# %%
#Convertir archivo filtrado a CSV
filtro12.to_csv("filtro12.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro12.csv")

# %%
#Filtro por filas
#filtro2= df.iloc[300:302,: ]
filtro2=df.iloc[ [50, 100, 200] , : ]  #filas no consecutivas 
filtro2

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("filtro2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro2.csv")

# %%
#Filtro por filas
filtro21= df.iloc[0:20,: ]
#filtro2=df.iloc[ [50, 100, 200] , : ]  #filas no consecutivas 
filtro21

# %%
#Convertir archivo filtrado a CSV
filtro21.to_csv("filtro21.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro21.csv")

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 2:5]
#filtro3=df.iloc[ : , [1,4,6]]  #columnas no consecutivas 
filtro3
# Out:
#          continent                     region  surface_area
# 0    North America                  Caribbean         193.0
# 1             Asia  Southern and Central Asia      652090.0
# 2           Africa             Central Africa     1246700.0
# 3    North America                  Caribbean          96.0
# 4           Europe            Southern Europe       28748.0
# ..             ...                        ...           ...
# 234           Asia                Middle East      527968.0
# 235         Europe            Southern Europe      102173.0
# 236         Africa            Southern Africa     1221037.0
# 237         Africa             Eastern Africa      752618.0
# 238         Africa             Eastern Africa      390757.0
#
# [239 rows x 3 columns]

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("filtro3.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro3.csv")

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 2:5]
filtro31=df.iloc[ : , [1,3,7]]  #columnas no consecutivas 
filtro31
# Out:
#              name                     region  life_expectancy
# 0           Aruba                  Caribbean             78.4
# 1     Afghanistan  Southern and Central Asia             45.9
# 2          Angola             Central Africa             38.3
# 3        Anguilla                  Caribbean             76.1
# 4         Albania            Southern Europe             71.6
# ..            ...                        ...              ...
# 234         Yemen                Middle East             59.8
# 235    Yugoslavia            Southern Europe             72.4
# 236  South Africa            Southern Africa             51.1
# 237        Zambia             Eastern Africa             37.2
# 238      Zimbabwe             Eastern Africa             37.8
#
# [239 rows x 3 columns]

# %%
#Convertir archivo filtrado a CSV
filtro31.to_csv("filtro31.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro31.csv")

# %%
#Filtro de filas vs columnas 
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=2)
# Out:
#      <input type="file" id="files-c6b7e5b8-31dc-4f18-9161-1a57448ae27b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6b7e5b8-31dc-4f18-9161-1a57448ae27b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas 
filtro4=df.loc[["Africa","North America"], ["head_of_state"]]
filtro4
# Out:
#                          head_of_state
# continent
# Africa         Jose Eduardo dos Santos
# Africa                   Pierre Buyoya
# Africa                 Mathieu Kerekou
# Africa                 Blaise Compaore
# Africa                 Festus G. Mogae
# ...                                ...
# North America    Arthur N. R. Robinson
# North America           George W. Bush
# North America             Elisabeth II
# North America             Elisabeth II
# North America           George W. Bush
#
# [95 rows x 1 columns]

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("filtro4.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro4.csv")

# %%
#Filtro de filas vs columnas 
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=3)
# Out:
#      <input type="file" id="files-474a0cdf-ae14-4c2a-b5d3-29cadfbb15cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-474a0cdf-ae14-4c2a-b5d3-29cadfbb15cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas 
filtro41=df.loc[["Caribbean","Antarctica"], ["government_form"]]
filtro41
# Out:
#                                          government_form
# region
# Caribbean   Nonmetropolitan Territory of The Netherlands
# Caribbean                  Dependent Territory of the uK
# Caribbean   Nonmetropolitan Territory of The Netherlands
# Caribbean                        Constitutional Monarchy
# Caribbean                        Constitutional Monarchy
# Caribbean                        Constitutional Monarchy
# Caribbean                           Socialistic Republic
# Caribbean                  Dependent Territory of the uK
# Caribbean                                       Republic
# Caribbean                                       Republic
# Caribbean                  Overseas Department of France
# Caribbean                        Constitutional Monarchy
# Caribbean                                       Republic
# Caribbean                        Constitutional Monarchy
# Caribbean                        Constitutional Monarchy
# ...

# %%
#Convertir archivo filtrado a CSV
filtro41.to_csv("filtro41.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro41.csv")

# %%
#Filtro por cabecera
filtro5=df.head(3)
filtro5
# Out:
#                           code         name      continent  surface_area  \
# region
# Caribbean                  ABW        Aruba  North America         193.0
# Southern and Central Asia  AFG  Afghanistan           Asia      652090.0
# Central Africa             AGO       Angola         Africa     1246700.0
#
#                            independence_year  population  life_expectancy  \
# region
# Caribbean                                NaN      103000             78.4
# Southern and Central Asia             1919.0    22720000             45.9
# Central Africa                        1975.0    12878000             38.3
#
#                               gnp  gnp_old             local_name  \
# region
# Caribbean                   828.0    793.0                  Aruba
# Southern and Central Asia  5976.0      NaN  Afganistan/Afqanestan
# Central Africa             6648.0   7984.0                 Angola
#
#                                                         government_form  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("filtro5.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro5.csv")

# %%
#Filtro por cabecera
filtro51=df.head(10)
filtro51
# Out:
#                           code                  name      continent  \
# region
# Caribbean                  ABW                 Aruba  North America
# Southern and Central Asia  AFG           Afghanistan           Asia
# Central Africa             AGO                Angola         Africa
# Caribbean                  AIA              Anguilla  North America
# Southern Europe            ALB               Albania         Europe
# Southern Europe            AND               Andorra         Europe
# Caribbean                  ANT  Netherlands Antilles  North America
# Middle East                ARE  united Arab Emirates           Asia
# South America              ARG             Argentina  South America
# Middle East                ARM               Armenia           Asia
#
#                            surface_area  independence_year  population  \
# region
# Caribbean                         193.0                NaN      103000
# ...

# %%
#Convertir archivo filtrado a CSV
filtro51.to_csv("filtro51.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro51.csv")

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
filtro6=df[df["independence_year"] > 1900]
filtro6

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("filtro6.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro6.csv")

# %%
#Filtro por comparacion
filtro61=df[df["population"] > 7000000]
filtro61
# Out:
#                           code          name      continent  surface_area  \
# region
# Southern and Central Asia  AFG   Afghanistan           Asia      652090.0
# Central Africa             AGO        Angola         Africa     1246700.0
# South America              ARG     Argentina  South America     2780400.0
# Australia and New Zealand  AuS     Australia        Oceania     7741220.0
# Western Europe             AuT       Austria         Europe       83859.0
# ...                        ...           ...            ...           ...
# Middle East                YEM         Yemen           Asia      527968.0
# Southern Europe            YuG    Yugoslavia         Europe      102173.0
# Southern Africa            ZAF  South Africa         Africa     1221037.0
# Eastern Africa             ZMB        Zambia         Africa      752618.0
# Eastern Africa             ZWE      Zimbabwe         Africa      390757.0
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro61.to_csv("filtro61.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro61.csv")

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
filtro7=df[(df["independence_year"] > 1900) & (df["population"] > 7000000)]
filtro7
# Out:
#                           code          name continent  surface_area  \
# region
# Southern and Central Asia  AFG   Afghanistan      Asia      652090.0
# Central Africa             AGO        Angola    Africa     1246700.0
# Australia and New Zealand  AuS     Australia   Oceania     7741220.0
# Western Europe             AuT       Austria    Europe       83859.0
# Middle East                AZE    Azerbaijan      Asia       86600.0
# ...                        ...           ...       ...           ...
# Middle East                YEM         Yemen      Asia      527968.0
# Southern Europe            YuG    Yugoslavia    Europe      102173.0
# Southern Africa            ZAF  South Africa    Africa     1221037.0
# Eastern Africa             ZMB        Zambia    Africa      752618.0
# Eastern Africa             ZWE      Zimbabwe    Africa      390757.0
#
#                            independence_year  population  life_expectancy  \
# region
# ...

# %%
#Filtro o
filtro8=df[(df["Periodo"] > 2006) | (df["Sexo"] == "Mujeres")]
filtro8
# Out:
#                      Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional                2005          1  Mujeres
# Aguascalientes          2005          1  Mujeres
# Baja California         2005          1  Mujeres
# Baja California Sur     2005          1  Mujeres
# Campeche                2005          1  Mujeres
# ...                      ...        ...      ...
# Veracruz                2022          1  Mujeres
# Yucat n                 2022          1  Hombres
# Yucat n                 2022          1  Mujeres
# Zacatecas               2022          1  Hombres
# Zacatecas               2022          1  Mujeres
#
#                     Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                    2690296
# Aguascalientes                                                28430
# Baja California                                              103697
# ...

# %%
#Filtro not
filtro9=df[~(df["Periodo"] >= 2006) & ~(df["Sexo"] == "Mujeres")]
filtro9
# Out:
#                      Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional                2005          1  Hombres
# Aguascalientes          2005          1  Hombres
# Baja California         2005          1  Hombres
# Baja California Sur     2005          1  Hombres
# Campeche                2005          1  Hombres
# ...                      ...        ...      ...
# Tamaulipas              2005          4  Hombres
# Tlaxcala                2005          4  Hombres
# Veracruz                2005          4  Hombres
# Yucat n                 2005          4  Hombres
# Zacatecas               2005          4  Hombres
#
#                     Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                    4384907
# Aguascalientes                                                56407
# Baja California                                              167651
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable1.csv")
